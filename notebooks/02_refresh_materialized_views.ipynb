# %%
# ============================================================
# 02_refresh_materialized_views.ipynb
# Refresca las vistas materializadas del modelo dimensional
# Ejecutado por finpay_semantic_job en cada ciclo tras el ETL
# ============================================================

spark.sql("REFRESH MATERIALIZED VIEW fintech_finpay.gold.fact_transactions")
spark.sql("REFRESH MATERIALIZED VIEW fintech_finpay.gold.dim_merchant")
spark.sql("REFRESH MATERIALIZED VIEW fintech_finpay.gold.dim_user")
spark.sql("REFRESH MATERIALIZED VIEW fintech_finpay.gold.dim_channel")
spark.sql("REFRESH MATERIALIZED VIEW fintech_finpay.gold.dim_date")
print("✓ Todas las vistas materializadas refrescadas exitosamente")
